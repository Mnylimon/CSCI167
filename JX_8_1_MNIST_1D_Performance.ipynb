# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-gv_ydxr2
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-gv_ydxr2
#   Resolved https://github.com/greydanus/mnist1d to commit 68cb6b2d1d3a956cc2e9035e5a9860b66e33d642
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post15) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post15) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post15) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post15) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post15) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post15) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post15) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post15) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post15) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post15) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post15) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post15) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post15) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post15) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post15) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post15) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post15) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post15-py3-none-any.whl size=14561 sha256=d838fa6b852aa2e51b22895487dc25195a926f62c5be3c0ae823a70a93dd1172
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3fw407_j/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post15

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.589780, train error 62.08,  test loss 1.672837, test error 68.00
# Epoch     1, train loss 1.338911, train error 48.85,  test loss 1.490407, test error 59.10
# Epoch     2, train loss 1.141330, train error 39.92,  test loss 1.335273, test error 52.90
# Epoch     3, train loss 1.003806, train error 35.90,  test loss 1.275853, test error 50.10
# Epoch     4, train loss 0.892277, train error 31.80,  test loss 1.237487, test error 47.60
# Epoch     5, train loss 0.794377, train error 27.30,  test loss 1.161761, test error 43.90
# Epoch     6, train loss 0.698437, train error 24.07,  test loss 1.109297, test error 42.00
# Epoch     7, train loss 0.617258, train error 20.57,  test loss 1.118208, test error 42.70
# Epoch     8, train loss 0.578784, train error 19.82,  test loss 1.130363, test error 40.70
# Epoch     9, train loss 0.502819, train error 17.32,  test loss 1.127004, test error 41.40
# Epoch    10, train loss 0.394286, train error 10.88,  test loss 1.048426, test error 37.90
# Epoch    11, train loss 0.357706, train error 9.30,  test loss 1.070608, test error 38.60
# Epoch    12, train loss 0.317345, train error 7.65,  test loss 1.070416, test error 38.50
# Epoch    13, train loss 0.300372, train error 7.68,  test loss 1.072117, test error 37.60
# Epoch    14, train loss 0.276901, train error 6.62,  test loss 1.113518, test error 38.50
# Epoch    15, train loss 0.250179, train error 5.72,  test loss 1.105176, test error 37.60
# Epoch    16, train loss 0.227318, train error 4.85,  test loss 1.115699, test error 37.80
# Epoch    17, train loss 0.214659, train error 4.60,  test loss 1.135678, test error 36.50
# Epoch    18, train loss 0.197728, train error 3.93,  test loss 1.164241, test error 38.50
# Epoch    19, train loss 0.177020, train error 3.20,  test loss 1.175685, test error 37.70
# Epoch    20, train loss 0.147643, train error 1.75,  test loss 1.155540, test error 37.50
# Epoch    21, train loss 0.138105, train error 1.60,  test loss 1.166598, test error 37.60
# Epoch    22, train loss 0.135106, train error 1.53,  test loss 1.201216, test error 38.00
# Epoch    23, train loss 0.130939, train error 1.78,  test loss 1.186497, test error 36.80
# Epoch    24, train loss 0.120300, train error 1.07,  test loss 1.205696, test error 37.30
# Epoch    25, train loss 0.113514, train error 0.97,  test loss 1.207082, test error 37.20
# Epoch    26, train loss 0.107984, train error 0.78,  test loss 1.237289, test error 37.40
# Epoch    27, train loss 0.102927, train error 0.65,  test loss 1.241144, test error 37.10
# Epoch    28, train loss 0.099102, train error 0.80,  test loss 1.234231, test error 37.40
# Epoch    29, train loss 0.093849, train error 0.62,  test loss 1.268795, test error 37.70
# Epoch    30, train loss 0.088706, train error 0.38,  test loss 1.262731, test error 37.40
# Epoch    31, train loss 0.086470, train error 0.38,  test loss 1.268919, test error 37.30
# Epoch    32, train loss 0.084750, train error 0.30,  test loss 1.268126, test error 37.20
# Epoch    33, train loss 0.082482, train error 0.38,  test loss 1.275146, test error 37.10
# Epoch    34, train loss 0.080434, train error 0.30,  test loss 1.278035, test error 37.00
# Epoch    35, train loss 0.078708, train error 0.22,  test loss 1.282323, test error 37.30
# Epoch    36, train loss 0.077313, train error 0.22,  test loss 1.287419, test error 36.80
# Epoch    37, train loss 0.076144, train error 0.28,  test loss 1.300040, test error 37.00
# Epoch    38, train loss 0.073801, train error 0.22,  test loss 1.301187, test error 37.30
# Epoch    39, train loss 0.072617, train error 0.20,  test loss 1.304199, test error 36.80
# Epoch    40, train loss 0.071184, train error 0.18,  test loss 1.306226, test error 37.20
# Epoch    41, train loss 0.070475, train error 0.18,  test loss 1.310343, test error 37.50
# Epoch    42, train loss 0.069699, train error 0.18,  test loss 1.314270, test error 36.90
# Epoch    43, train loss 0.068937, train error 0.18,  test loss 1.317819, test error 37.20
# Epoch    44, train loss 0.068154, train error 0.15,  test loss 1.320375, test error 37.20
# Epoch    45, train loss 0.067588, train error 0.12,  test loss 1.322985, test error 37.40
# Epoch    46, train loss 0.066730, train error 0.15,  test loss 1.324844, test error 37.30
# Epoch    47, train loss 0.066244, train error 0.12,  test loss 1.330904, test error 37.30
# Epoch    48, train loss 0.065371, train error 0.12,  test loss 1.330316, test error 37.30
# Epoch    49, train loss 0.064734, train error 0.12,  test loss 1.329938, test error 37.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %% [markdown]
# I don't think so. I think optimizing the hyperparameters this was will make the model expect or be to used to the train data. So it would struggle with new or unseen data. So it wouldn't be a good estimate of the true test performance.
#
# Also I think I made the model worse after messing with the hyperparameters too much. Even after changing everything back to the original values and amounts. The plotted results are not the same as my initial run in my runtime and have higher losses.
